# %%
anchor_mapall = [0.43090283077506586, 0.46275136379639137, 0.48533838573797733, 0.4998520787957119, 0.5091406644880858, 0.5148986722992541]
anchor_map50 = [0.5876396628348844, 0.6238729172041891, 0.6463052077260992, 0.6630975853042104, 0.6737612317201819, 0.6796478202473217]
anchor_map75 = [0.46468562587928286, 0.4989560210564381, 0.5259281458982823, 0.5444028506461864, 0.5532850822624382, 0.5611781599015023]

attn_mapall = [0.43279942171419145, 0.4646816836322871, 0.4879396373193919, 0.5007921405199903, 0.5100313373712585, 0.513959521938109]
attn_map50 = [0.5869563856769775, 0.6226633719826997, 0.6494565597705888, 0.6636674783696866, 0.6737841454928188, 0.6771595774951291]
attn_map75 = [0.4682910281542503, 0.5039784612906166, 0.5297455238191453, 0.5457979236533483, 0.554439208552288, 0.5608976749224583]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

plt.plot(range(1, 7), anchor_map50, label="cheng-anchor map50")
plt.plot(range(1, 7), anchor_map75, label="cheng-anchor map75")
plt.plot(range(1, 7), anchor_mapall, label="cheng-anchor map")

plt.plot(range(1, 7), attn_map50, label="cheng-attn map50")
plt.plot(range(1, 7), attn_map75, label="cheng-attn map75")
plt.plot(range(1, 7), attn_mapall, label="cheng-attn map")

plt.hlines(0.6892116347098692, xmin=1, xmax=6, label="non-compressed map50", colors="green", linestyle="dotted")
plt.hlines(0.5714493823958758, xmin=1, xmax=6, label="non-compressed map75", colors="orange", linestyle="dotted")
plt.hlines(0.5244860048906652, xmin=1, xmax=6, label="non-compressed map", colors="blue", linestyle="dotted")

plt.title("Object detection")
plt.xlabel("Quality")
plt.legend(loc="upper left");

# %% [markdown]
# ---
